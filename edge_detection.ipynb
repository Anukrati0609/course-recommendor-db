# %% [markdown]
# <a href="https://colab.research.google.com/github/Anukrati0609/course-recommendor-db/blob/main/edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img= cv2.imread('/content/drive/MyDrive/ColabNotebooks/JEC-Jabalpur.webp')
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off')
plt.title("original image")
plt.show()

# %%
gray=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')
plt.axis('off')
plt.title('grayscale image')
plt.show()

# %%
edges1= cv2.Canny(gray,100,200)
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.title('edge detected image')
plt.show()

# %%
edges2= cv2.Canny(gray,100,400)
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.title('edge detected image')
plt.show()

# %%
edges3= cv2.Canny(gray,250,500)
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.title('edge detected image')
plt.show()

# %%
#edges1 = cv2.Canny(gray, 50, 150)
#edges2 = cv2.Canny(gray, 100, 200)
#edges3 = cv2.Canny(gray, 150, 250)


fig, ax = plt.subplots(1, 3, figsize=(18,6))


ax[0].imshow(edges1, cmap='gray')
ax[0].set_title("Edges 100-200")
ax[0].axis('off')

ax[1].imshow(edges2, cmap='gray')
ax[1].set_title("Edges 100-400")
ax[1].axis('off')

ax[2].imshow(edges3, cmap='gray')
ax[2].set_title("Edges 250-500")
ax[2].axis('off')

plt.show()

# %%
import seaborn as sns
sns.histplot(gray.ravel(), bins=256, color='gray')
plt.title("Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")
plt.show()
